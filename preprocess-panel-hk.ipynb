# %% [markdown]
# # RWI-GEO-RED Panel Data Preprocessing: Household Purchasing Power (HK)
#
# ## About the Dataset
#
#
# ### Dataset: CampusFile_HK_cities.csv
#
# ### Data Structure
# - **Temporal Coverage**: Panel data across multiple years
# - **Geographic Coverage**: 15 largest cities in Germany

# %% [markdown]
# ## Setup: Load Required Libraries

# %%
library(dplyr)
library(ggplot2)
library(tidyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Load Hauskauf data

# %%
raw_data <- read.csv('data/RWI-GEO-RED/panel-15-largest-cities-germany/CampusFile_HK_cities.csv')

# %%
df <- raw_data
total_rows_in_raw_data = nrow(df)
total_rows_in_raw_data
# Out:
# [1] 412816

# %% [markdown]
# # Preprocess the data

# %%
summary(df)
# Out:
#       obid                plz          kaufpreis       mieteinnahmenpromonat
#  Min.   : 25586984   Min.   :   -9   Min.   :  29000   Min.   :    -9.0
#  1st Qu.: 59750323   1st Qu.:13503   1st Qu.: 260000   1st Qu.:    -9.0
#  Median : 84395616   Median :30539   Median : 399900   Median :    -9.0
#  Mean   : 89238240   Mean   :36025   Mean   : 506339   Mean   :   197.9
#  3rd Qu.:116947671   3rd Qu.:50765   3rd Qu.: 649900   3rd Qu.:    -9.0
#  Max.   :156377699   Max.   :99571   Max.   :2444444   Max.   :100000.0
#    heizkosten         baujahr     letzte_modernisierung  wohnflaeche
#  Min.   : -9.000   Min.   :1500   Min.   :  -9.0        Min.   : 54.0
#  1st Qu.: -9.000   1st Qu.:1952   1st Qu.:  -9.0        1st Qu.:120.0
#  Median : -8.000   Median :1979   Median :  -9.0        Median :145.0
#  Mean   : -8.492   Mean   :1974   Mean   : 327.5        Mean   :174.8
#  3rd Qu.: -8.000   3rd Qu.:2009   3rd Qu.:  -9.0        3rd Qu.:198.2
#  Max.   :150.000   Max.   :2024   Max.   :2018.0        Max.   :740.0
#  grundstuecksflaeche  nutzflaeche       zimmeranzahl     nebenraeume
#  Min.   :  -9.0      Min.   :  -9.00   Min.   :-9.000   Min.   :-9.000
#  1st Qu.: 245.0      1st Qu.:  -9.00   1st Qu.: 4.000   1st Qu.:-9.000
#  Median : 428.0      Median :   0.00   Median : 5.000   Median :-6.000
#  Mean   : 513.5      Mean   :  44.33   Mean   : 6.016   Mean   :-7.491
#  3rd Qu.: 667.0      3rd Qu.:  70.00   3rd Qu.: 7.000   3rd Qu.:-6.000
#  Max.   :5000.0      Max.   :1000.00   Max.   :25.000   Max.   : 0.000
#   schlafzimmer      badezimmer     parkplatzpreis     ev_kennwert
#  Min.   :-9.000   Min.   :-9.000   Min.   :   -9.0   Min.   : -9.00
#  1st Qu.:-9.000   1st Qu.:-9.000   1st Qu.:   -9.0   1st Qu.: -9.00
#  Median : 2.000   Median : 1.000   Median :   -9.0   Median : -9.00
#  Mean   :-1.595   Mean   :-1.558   Mean   :  857.8   Mean   : 42.75
#  3rd Qu.: 4.000   3rd Qu.: 2.000   3rd Qu.:   -9.0   3rd Qu.: 81.10
#  Max.   :99.000   Max.   :15.000   Max.   :50000.0   Max.   :600.00
#   laufzeittage     immobilientyp denkmalobjekt     einbaukueche
#  Min.   :   0.00   Min.   :1     Min.   :-9.000   Min.   :-8
#  1st Qu.:  10.00   1st Qu.:1     1st Qu.: 0.000   1st Qu.:-8
#  Median :  28.00   Median :1     Median : 0.000   Median :-8
#  Mean   :  57.28   Mean   :1     Mean   :-1.608   Mean   :-8
#  3rd Qu.:  61.00   3rd Qu.:1     3rd Qu.: 0.000   3rd Qu.:-8
#  Max.   :3969.00   Max.   :1     Max.   : 1.000   Max.   :-8
#  einliegerwohnung ev_wwenthalten     ferienhaus       foerderung
#  Min.   :-9.000   Min.   :-9.000   Min.   :-9.000   Min.   :-8
#  1st Qu.:-9.000   1st Qu.:-9.000   1st Qu.: 0.000   1st Qu.:-8
#  Median : 0.000   Median :-9.000   Median : 0.000   Median :-8
#  Mean   :-2.279   Mean   :-6.629   Mean   :-1.531   Mean   :-8
#  3rd Qu.: 0.000   3rd Qu.: 0.000   3rd Qu.: 0.000   3rd Qu.:-8
#  Max.   : 1.000   Max.   : 1.000   Max.   : 1.000   Max.   :-8
#     gaestewc           garten   kaufvermietet        keller
#  Min.   :-9.0000   Min.   :-8   Min.   :-9.000   Min.   :-9.0000
#  1st Qu.: 0.0000   1st Qu.:-8   1st Qu.:-9.000   1st Qu.: 0.0000
#  Median : 0.0000   Median :-8   Median : 0.000   Median : 0.0000
#  Mean   :-0.8081   Mean   :-8   Mean   :-2.538   Mean   :-0.8643
#  3rd Qu.: 1.0000   3rd Qu.:-8   3rd Qu.: 0.000   3rd Qu.: 1.0000
#  Max.   : 1.0000   Max.   :-8   Max.   : 1.000   Max.   : 1.0000
#    parkplatz     rollstuhlgerecht    bauphase      ausstattung
#  Min.   :-9.00   Min.   :-9.00    Min.   :-7.00   Min.   :-7.000
#  1st Qu.:-9.00   1st Qu.:-9.00    1st Qu.:-7.00   1st Qu.:-7.000
#  Median :-9.00   Median :-9.00    Median :-7.00   Median :-7.000
#  Mean   :-5.51   Mean   :-4.71    Mean   :-4.36   Mean   :-2.663
#  3rd Qu.: 1.00   3rd Qu.: 0.00    3rd Qu.: 1.00   3rd Qu.: 3.000
#  Max.   : 1.00   Max.   : 1.00    Max.   : 3.00   Max.   : 4.000
#  energieeffizienzklasse energieausweistyp haustier_erlaubt  heizungsart
#  Min.   :-9.000         Min.   :-7.000    Min.   :-8       Min.   :-7.000
#  1st Qu.:-7.000         1st Qu.:-7.000    1st Qu.:-8       1st Qu.:-7.000
#  Median :-7.000         Median :-7.000    Median :-8       Median :12.000
#  Mean   :-5.367         Mean   :-4.043    Mean   :-8       Mean   : 5.988
#  3rd Qu.:-7.000         3rd Qu.: 1.000    3rd Qu.:-8       3rd Qu.:13.000
#  Max.   : 9.000         Max.   : 2.000    Max.   :-8       Max.   :13.000
#  kategorie_Haus   objektzustand       ergg_1km              blid
#  Min.   :-9.000   Min.   :-7.0000   Length:412816      Min.   : 1.000
#  1st Qu.: 1.000   1st Qu.:-7.0000   Class :character   1st Qu.: 5.000
#  Median : 3.000   Median : 1.0000   Mode  :character   Median : 5.000
#  Mean   : 3.815   Mean   : 0.9038                      Mean   : 7.174
#  3rd Qu.: 6.000   3rd Qu.: 7.0000                      3rd Qu.:11.000
#  Max.   :15.000   Max.   :10.0000                      Max.   :16.000
#     gid2019            kid2019           bef1             bef2
#  Min.   : 2000000   Min.   : 2000   Min.   :-9.000   Min.   :-9.000
#  1st Qu.: 5111000   1st Qu.: 5111   1st Qu.:-9.000   1st Qu.:-9.000
#  Median : 5913000   Median : 5913   Median :-9.000   Median :-9.000
#  Mean   : 7383481   Mean   : 7383   Mean   :-4.957   Mean   :-8.907
#  3rd Qu.:11000000   3rd Qu.:11000   3rd Qu.: 1.000   3rd Qu.:-9.000
#  Max.   :14713000   Max.   :14713   Max.   :27.000   Max.   :25.000
#      bef10         bef9         bef8         bef7             bef6
#  Min.   :-9   Min.   :-9   Min.   :-9   Min.   :-9.000   Min.   :-9.000
#  1st Qu.:-9   1st Qu.:-9   1st Qu.:-9   1st Qu.:-9.000   1st Qu.:-9.000
#  Median :-9   Median :-9   Median :-9   Median :-9.000   Median :-9.000
#  Mean   :-9   Mean   :-9   Mean   :-9   Mean   :-8.999   Mean   :-8.999
#  3rd Qu.:-9   3rd Qu.:-9   3rd Qu.:-9   3rd Qu.:-9.000   3rd Qu.:-9.000
#  Max.   :-9   Max.   :-9   Max.   :-9   Max.   :14.000   Max.   :24.000
#       bef5             bef4             bef3           anbieter
#  Min.   :-9.000   Min.   :-9.000   Min.   :-9.000   Min.   :-9.000
#  1st Qu.:-9.000   1st Qu.:-9.000   1st Qu.:-9.000   1st Qu.:-9.000
#  Median :-9.000   Median :-9.000   Median :-9.000   Median :-9.000
#  Mean   :-8.998   Mean   :-8.993   Mean   :-8.906   Mean   :-5.206
#  3rd Qu.:-9.000   3rd Qu.:-9.000   3rd Qu.:-9.000   3rd Qu.: 2.000
#  Max.   :25.000   Max.   :25.000   Max.   :25.000   Max.   : 9.000
#      spell       dataset_version        adat               edat
#  Min.   : 1.00   Length:412816      Length:412816      Length:412816
#  1st Qu.: 1.00   Class :character   Class :character   Class :character
#  Median : 1.00   Mode  :character   Mode  :character   Mode  :character
#  Mean   : 1.53
#  3rd Qu.: 2.00
#  Max.   :59.00
#    price_sqm
#  Min.   : 242.4
#  1st Qu.:1811.1
#  Median :2631.8
#  Mean   :3000.9
#  3rd Qu.:3859.1
#  Max.   :9603.3

# %% [markdown]
# ## Range of the house inserate

# %%
# adat -> the date of the inserat
df %>%
    summarise(
        min_adat = min(as.Date(paste0(adat, "-01")), na.rm = TRUE),
        max_adat = max(as.Date(paste0(adat, "-01")), na.rm = TRUE)
    )
# Out:
#   min_adat   max_adat
# 1 2007-01-01 2024-12-01

# %% [markdown]
# data goes from 2007 to 2024

# %% [markdown]
# ## Extract only berlin samples
#
# We only want to createt a model of the berlin real estate listings

# %%
extract_berlin_samples <- function(source_df) {
    df_berlin <- subset(source_df, !is.na(plz) &
        as.integer(as.character(plz)) >= 10115 &
        as.integer(as.character(plz)) <= 14199)
    return (
        df_berlin
    )
}

# %%
dfb = extract_berlin_samples(df)

# %%
cat("Total rows in raw data:", total_rows_in_raw_data, "\n")
cat("Rows in Berlin sample:", nrow(dfb), "\n")
cat("Percentage of Berlin rows:", round(100 * nrow(dfb) / total_rows_in_raw_data, 2), "%\n")
# Out:
# Total rows in raw data: 412816
# Rows in Berlin sample: 89753
# Percentage of Berlin rows: 21.74 %

# %% [markdown]
# ## Sentinel cleanup
#
# The data is full of placeholder integer values that symbolise missing data
#
# - -9 -> missing data
# - -8 -> did not answer
#
# etc ...
#
# these need to be cleaned up

# %%
# util function for replacing sentinel values with NA
sentinels <- c(-9, -8, -7, -6, -5)
replace_sentinels <- function(x, s = sentinels) {
  x[x %in% s] <- NA
  return (
    x
  )
}

# %%
c(colnames(df))
# Out:
#  [1] "obid"                   "plz"                    "kaufpreis"
#  [4] "mieteinnahmenpromonat"  "heizkosten"             "baujahr"
#  [7] "letzte_modernisierung"  "wohnflaeche"            "grundstuecksflaeche"
# [10] "nutzflaeche"            "zimmeranzahl"           "nebenraeume"
# [13] "schlafzimmer"           "badezimmer"             "parkplatzpreis"
# [16] "ev_kennwert"            "laufzeittage"           "immobilientyp"
# [19] "denkmalobjekt"          "einbaukueche"           "einliegerwohnung"
# [22] "ev_wwenthalten"         "ferienhaus"             "foerderung"
# [25] "gaestewc"               "garten"                 "kaufvermietet"
# [28] "keller"                 "parkplatz"              "rollstuhlgerecht"
# [31] "bauphase"               "ausstattung"            "energieeffizienzklasse"
# [34] "energieausweistyp"      "haustier_erlaubt"       "heizungsart"
# [37] "kategorie_Haus"         "objektzustand"          "ergg_1km"
# [40] "blid"                   "gid2019"                "kid2019"
# [43] "bef1"                   "bef2"                   "bef10"
# [46] "bef9"                   "bef8"                   "bef7"
# [49] "bef6"                   "bef5"                   "bef4"
# [52] "bef3"                   "anbieter"               "spell"
# [55] "dataset_version"        "adat"                   "edat"
# [58] "price_sqm"

# %%
cols_with_sentinels <- c(colnames(df))
df[cols_with_sentinels] <- lapply(df[cols_with_sentinels], replace_sentinels)
